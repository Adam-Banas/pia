# %%
print('asdf')
# Out:
# asdf

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_excel("data_source/wig20_to_2023-11-06_indeksy.xls")

df.head()
# Out:
#          Data  Nazwa          ISIN Waluta  Kurs otwarcia  Kurs max  Kurs min  \
# 0  1994-04-18  WIG20  PL9999999987    PLN         1050.0    1050.0    1050.0
# 1  1994-04-19  WIG20  PL9999999987    PLN         1124.0    1124.0    1124.0
# 2  1994-04-21  WIG20  PL9999999987    PLN         1304.0    1304.0    1304.0
# 3  1994-04-25  WIG20  PL9999999987    PLN         1350.0    1350.0    1350.0
# 4  1994-04-26  WIG20  PL9999999987    PLN         1216.0    1216.0    1216.0
#
#    Kurs zamknięcia  Zmiana  Wolumen  Liczba Transakcji  Obrót  \
# 0           1050.5     0.0        0                  0    0.0
# 1           1124.9     7.0        0                  0    0.0
# 2           1304.8    15.0        0                  0    0.0
# 3           1350.1     3.0        0                  0    0.0
# 4           1216.2    -9.0        0                  0    0.0
#
#    Liczba otwartych pozycji  Wartość otwartych pozycji  Cena nominalna
# ...

# %%
df.describe()
# Out:
#        Kurs otwarcia     Kurs max     Kurs min  Kurs zamknięcia       Zmiana  \
# count    7361.000000  7361.000000  7361.000000      7361.000000  7361.000000
# mean     1993.376896  2008.677078  1976.821460      1992.981543     0.024057
# std       619.140861   623.826600   612.839974       618.433155     1.697136
# min       577.000000   577.000000   577.000000       577.900000   -13.280000
# 25%      1579.400000  1594.500000  1565.070000      1579.180000    -0.840000
# 50%      1995.590000  2012.870000  1977.170000      1994.910000     0.000000
# 75%      2372.450000  2388.590000  2355.750000      2371.140000     0.860000
# max      3935.470000  3940.530000  3910.960000      3917.870000    15.000000
#
#        Wolumen  Liczba Transakcji         Obrót  Liczba otwartych pozycji  \
# count   7361.0             7361.0  7.361000e+03                    6962.0
# mean       0.0                0.0  5.390185e+05                       0.0
# ...

# %%
df.sort_values(by="Zmiana")
# Out:
#             Data  Nazwa          ISIN Waluta  Kurs otwarcia  Kurs max  \
# 6444  2020-03-12  WIG20  PL9999999987    NaN        1450.71   1450.71
# 849   1997-10-28  WIG20  PL9999999987    PLN        1466.70   1466.70
# 6935  2022-02-24  WIG20  PL9999999987    NaN        1929.14   1929.14
# 1053  1998-08-27  WIG20  PL9999999987    PLN        1313.10   1313.10
# 1148  1999-01-13  WIG20  PL9999999987    PLN        1291.00   1291.00
# ...          ...    ...           ...    ...            ...       ...
# 6936  2022-02-25  WIG20  PL9999999987    NaN        1850.34   1993.78
# 3622  2008-11-24  WIG20  PL9999999987    PLN        1614.83   1721.45
# 1057  1998-09-02  WIG20  PL9999999987    PLN        1179.00   1212.60
# 850   1997-10-29  WIG20  PL9999999987    PLN        1577.10   1589.30
# 2     1994-04-21  WIG20  PL9999999987    PLN        1304.00   1304.00
#
#       Kurs min  Kurs zamknięcia  Zmiana  Wolumen  Liczba Transakcji  \
# ...

# %%
df.iloc[:2, :5]
# Out:
#          Data  Nazwa          ISIN Waluta  Kurs otwarcia
# 0  1994-04-18  WIG20  PL9999999987    PLN         1050.0
# 1  1994-04-19  WIG20  PL9999999987    PLN         1124.0
